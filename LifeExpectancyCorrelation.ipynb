# %% [markdown]
# # To Determine which Factors Correlate with Longer Life Expectancy

# %% [markdown]
# ## Load in Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Data

# %%
dataset = pd.read_csv('C:/Users/darli/Downloads/ProjectsPortfolio/who-revised.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0      Country  Year  Life.expectancy  Adult.Mortality  \
# 0           1  Afghanistan  2015             65.0            263.0
# 1           2  Afghanistan  2014             59.9            271.0
# 2           3  Afghanistan  2013             59.9            268.0
# 3           4  Afghanistan  2012             59.5            272.0
# 4           5  Afghanistan  2011             59.2            275.0
#
#    infant.deaths  Alcohol  Hepatitis.B  Measles  under.five.deaths  Polio  \
# 0             62     0.01         65.0     1154                 83    6.0
# 1             64     0.01         62.0      492                 86   58.0
# 2             66     0.01         64.0      430                 89   62.0
# 3             69     0.01         67.0     2787                 93   67.0
# 4             71     0.01         68.0     3013                 97   68.0
#
#    Total.expenditure  Diphtheria  HIV.AIDS         GDP  Population  \
# ...

# %% [markdown]
# ## Data  Wrangling

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2936 entries, 0 to 2935
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       2936 non-null   int64
#  1   Country                          2936 non-null   object
#  2   Year                             2936 non-null   int64
#  3   Life.expectancy                  2928 non-null   float64
#  4   Adult.Mortality                  2928 non-null   float64
#  5   infant.deaths                    2936 non-null   int64
#  6   Alcohol                          2742 non-null   float64
#  7   Hepatitis.B                      2383 non-null   float64
#  8   Measles                          2936 non-null   int64
#  9   under.five.deaths                2936 non-null   int64
#  10  Polio                            2917 non-null   float64
#  11  Total.expenditure                2710 non-null   float64
# ...

# %% [markdown]
# ### Drop Non-Continuous Variables

# %%
dataset = dataset.drop(['Country'], axis=1)

# %%
dataset.head()
# Out:
#    Unnamed: 0  Year  Life.expectancy  Adult.Mortality  infant.deaths  Alcohol  \
# 0           1  2015             65.0            263.0             62     0.01
# 1           2  2014             59.9            271.0             64     0.01
# 2           3  2013             59.9            268.0             66     0.01
# 3           4  2012             59.5            272.0             69     0.01
# 4           5  2011             59.2            275.0             71     0.01
#
#    Hepatitis.B  Measles  under.five.deaths  Polio  Total.expenditure  \
# 0         65.0     1154                 83    6.0               8.16
# 1         62.0      492                 86   58.0               8.18
# 2         64.0      430                 89   62.0               8.13
# 3         67.0     2787                 93   67.0               8.52
# 4         68.0     3013                 97   68.0               7.87
#
#    Diphtheria  HIV.AIDS         GDP  Population  thinness..1.19.years  \
# ...

# %% [markdown]
# ### Rename the thinness..1.19.years Column

# %%
dataset.rename(columns={'thinness..1.19.years':'thinness.10.19.years'}, inplace=True)

# %% [markdown]
# ## Create a Correlation Matrix

# %%
dataset.corr(method='pearson')
# Out:
#                                  Unnamed: 0      Year  Life.expectancy  \
# Unnamed: 0                         1.000000 -0.003865        -0.015529
# Year                              -0.003865  1.000000         0.170033
# Life.expectancy                   -0.015529  0.170033         1.000000
# Adult.Mortality                    0.037140 -0.079052        -0.696359
# infant.deaths                     -0.029594 -0.037226        -0.196557
# Alcohol                           -0.064125 -0.051914         0.404877
# Hepatitis.B                       -0.020658  0.103775         0.256762
# Measles                           -0.022502 -0.082363        -0.157586
# under.five.deaths                 -0.025565 -0.042746        -0.222529
# Polio                              0.017608  0.093666         0.465556
# Total.expenditure                  0.054932  0.091046         0.218086
# Diphtheria                        -0.006946  0.133869         0.479495
# ...

# %%
dataset.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style type="text/css">
# #T_18e7f_row0_col0, #T_18e7f_row1_col1, #T_18e7f_row2_col2, #T_18e7f_row3_col3, #T_18e7f_row4_col4, #T_18e7f_row4_col8, #T_18e7f_row5_col5, #T_18e7f_row6_col6, #T_18e7f_row7_col7, #T_18e7f_row8_col4, #T_18e7f_row8_col8, #T_18e7f_row9_col9, #T_18e7f_row10_col10, #T_18e7f_row11_col11, #T_18e7f_row12_col12, #T_18e7f_row13_col13, #T_18e7f_row14_col14, #T_18e7f_row15_col15, #T_18e7f_row16_col16, #T_18e7f_row17_col17, #T_18e7f_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_18e7f_row0_col1, #T_18e7f_row6_col3, #T_18e7f_row8_col17, #T_18e7f_row14_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_18e7f_row0_col2, #T_18e7f_row4_col9, #T_18e7f_row7_col10, #T_18e7f_row14_col18 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_18e7f_row0_col3, #T_18e7f_row8_col5, #T_18e7f_row14_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
#  Life expectancy is correlated with GDP, Income composition of sources, and schooling.
